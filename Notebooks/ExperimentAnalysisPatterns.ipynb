# %% [markdown]
# # Experiment Analysis
# In this notebook we will evaluate the results form the experiments executed. For each experiment, one parameter is changed and all others were kept constant as to determine the effect of one variable.
#
# **The goals of this analysis are:**
# 1. Determine the relationship of the number of parameters in the neural network and the number of timesteps in the dataset
# 2. Determine what effect increasing the number patterns are w.r.t. this relationship
# 3. Investigate what changing the input size has on the neural network
# 4. Determine what effect sparsity has on the capacity of the neural networks
# 5. Investigate which activation function lead to the highest retention of information
# 6. What type of network is able to retain the most information

# %% [markdown]
# To determine whether a relationshop exists between the variable being investigated and the number of required parameters in each respective neural network, the Pearson correlation coefficient is used. The domain of this metric lies between -1 and +1 or in mathematical notation $P \in [-1, 1]$. If there exists a strong positive relationship between variables, the Pearson coefficient will approach +1 and for the negative case -1.

# %%
import pandas as pd 
import numpy as np
import scipy
import sklearn
import pandas as pd
from sqlalchemy import Column, Integer, String
from sqlalchemy import create_engine, Column
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Number of Patterns Analysis

# %%
df = pd.read_csv("patterns.csv", delimiter=",")
df.head(5)
# Out:
#           folder_root  run_count  f_score  timesteps  sparsity_length  \
# 0  INFO:root:patterns          1      1.0          1                0
# 1  INFO:root:patterns          1      1.0          1                0
# 2  INFO:root:patterns          1      1.0          1                0
# 3  INFO:root:patterns          1      1.0          1                0
# 4  INFO:root:patterns          1      1.0          1                0
#
#    case_type  num_input  num_output  num_patterns_to_recall  \
# 0          1         10           2                       2
# 1          1         10           2                       2
# 2          1         10           2                       2
# 3          1         10           2                       2
# 4          1         10           2                       2
#
#    num_patterns_total     ...      batch_size  epocs  activation_function  \
# 0                1024     ...              10      4              softmax
# 1                1024     ...              10      4                  elu
# 2                1024     ...              10      8                 selu
# 3                1024     ...              10     24             softplus
# 4                1024     ...              10      4             softsign
#
#   num_correctly_identified architecture  full_network_json   model_history  \
# 0                        0          NaN                 NaN            NaN
# 1                        0          NaN                 NaN            NaN
# 2                        0          NaN                 NaN            NaN
# 3                        0          NaN                 NaN            NaN
# 4                        0          NaN                 NaN            NaN
#
#   full_network   input_set  output_set
# 0           NaN        NaN         NaN
# 1           NaN        NaN         NaN
# 2           NaN        NaN         NaN
# 3           NaN        NaN         NaN
# 4           NaN        NaN         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Number of parameters $\varpropto$ patterns

# %% [markdown]
# ### Overall

# %%
from matplotlib import pyplot
def plot_by_filter(x_col, 
                   y_col, 
                   x_label='Sparsity length',
                   y_label='Number of network parameters',
                   title="Effect of sparsity on the number of parameters \n in a neural network with activation ", 
                   hue="network_type", 
                   filter_col="activation_function", 
                   filter_val="tanh",
                   legend_title="NN TYPE",
                  df=None):
    sns.set_style("whitegrid")
    a4_dims = (6, 2.25)
    fig, ax = pyplot.subplots(figsize=a4_dims)
    ax.set(xlabel=x_label, 
       ylabel=y_label )
    if filter_val is not None:
        ax = sns.pointplot(ax=ax, x=x_col, y=y_col, hue=hue, 
                          marker='o',  markersize=5, ci=None,
                          data = df[df[filter_col] == filter_val])
       
        ax.axes.set_title(title + filter_val,
                          fontsize=12, y=1.05)
        ax.legend(title=filter_val.upper(), loc='center right', bbox_to_anchor=(1.37, 0.5), ncol=1)
    else:
        ax = sns.pointplot(ax=ax, x=x_col, y=y_col, hue=hue, 
                          marker='o',  markersize=5, ci=None,
                          data = df)
        ax.axes.set_title(title, fontsize=12, y=1.05)
        ax.legend(title=legend_title, loc='center right', bbox_to_anchor=(1.37, 0.5), ncol=1)

    # plt.legend()
filter_col = "network_type"
filter_1 = "num_patterns_to_recall"
x_col = "num_patterns_to_recall"
x_label = "Number of Patterns"
plot_by_filter(x_col=x_col, 
               y_col="num_network_parameters",
               x_label=x_label,
               y_label='Number of network parameters',
               title="Effect of sparsity on the number of parameters " + 
                       "\n in a neural network over all activation functions", 
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)

# %%
filter_col = "network_type"
filter_col_1 = x_col
for filter_val in df[filter_col].unique():
    df_temp = df[df[filter_col] == filter_val]
    df_temp = df_temp.groupby([x_col, "network_type"]).agg({"num_network_parameters": "mean"}).to_records()
    df_temp = pd.DataFrame.from_records(df_temp)
    df_temp[x_col] = df_temp[x_col].astype(float)
    df_temp["num_network_parameters"] = df_temp["num_network_parameters"].astype(float)
    
    print("Pearson Correlation Between "+x_label+" length and Number of Network Parameters for", filter_val, df_temp[x_col].corr(df_temp["num_network_parameters"]))
# Out:
# Pearson Correlation Between Number of Patterns length and Number of Network Parameters for lstm 0.25056690829579925
# Pearson Correlation Between Number of Patterns length and Number of Network Parameters for gru 0.9959451115405912
# Pearson Correlation Between Number of Patterns length and Number of Network Parameters for elman_rnn 0.9708614013900211

# %% [markdown]
# ### Discussion of results
#
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#                             #### TODOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
#
# From the Pearson coefficient, it is clear that there is a small negative relationship between the number of timesteps and the number of network parameters required for the Elman RNN. For the LSTM and GRU it seems that the relationship is steadily increasing with the number of required timesteps.
#
# Upon inspecting the graph of the results however, it is more apparent that this small correlation is due to variablity in the experiment during training. Thus it is safe to assume that there is no correlation between the number of network parameters required and the number of time steps with sparsity, number of patterns and output nodes fixed.

# %% [markdown]
# ### Effect of sparsity of patterns on networks with specific activation functions

# %%
filter_col = "activation_function"
filter_col_1 = x_col
for filter_val in df[filter_col].unique():
    df_temp = df[(df[filter_col] == filter_val)]
    df_temp = df_temp.groupby([filter_col_1]).agg({"num_network_parameters": "mean"}).to_records()
    df_temp = pd.DataFrame.from_records(df_temp)
    df_temp[filter_col_1] = df_temp[filter_col_1].astype(float)
    df_temp["num_network_parameters"] = df_temp["num_network_parameters"].astype(float)
    
    print("Pearson Correlation Between "+x_label+" and Number of Network Parameters for", filter_val, df_temp[filter_col_1].corr(df_temp["num_network_parameters"]))
# Out:
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for softmax 0.15272893318602285
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elu 0.27533972888233155
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for selu -0.3244323110127172
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for softplus 0.8968195705332023
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for softsign 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for tanh 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for hard_sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for relu 0.8454280584142784
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for linear 0.999831182075961

# %% [markdown]
# ### Discussion of activation functions  ∝ time steps

# %%
filter_col = "activation_function"
for filter_val in df[filter_col].unique():
    for filter_val_1 in df["network_type"].unique():
        df_temp = df[df["network_type"] == filter_val_1]
        df_temp = df[df[filter_col] == filter_val]
        df_temp = df_temp.groupby([filter_col_1]).agg({"num_network_parameters": "mean"}).to_records()
        df_temp = pd.DataFrame.from_records(df_temp)
        df_temp[x_col] = df_temp[filter_col_1].astype(float)
        df_temp["num_network_parameters"] = df_temp["num_network_parameters"].astype(float)

        print("Pearson Correlation Between "+x_label+" and Number of Network Parameters for", filter_val_1 + " "+ filter_val, df_temp[filter_col_1].corr(df_temp["num_network_parameters"]))
# Out:
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm softmax 0.15272893318602285
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru softmax 0.15272893318602285
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn softmax 0.15272893318602285
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm elu 0.27533972888233155
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru elu 0.27533972888233155
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn elu 0.27533972888233155
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm selu -0.3244323110127172
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru selu -0.3244323110127172
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn selu -0.3244323110127172
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm softplus 0.8968195705332023
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru softplus 0.8968195705332023
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn softplus 0.8968195705332023
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm softsign 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru softsign 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn softsign 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm tanh 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru tanh 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn tanh 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm hard_sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru hard_sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn hard_sigmoid 0.9665124564807963
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm relu 0.8454280584142784
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru relu 0.8454280584142784
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn relu 0.8454280584142784
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for lstm linear 0.999831182075961
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for gru linear 0.999831182075961
# Pearson Correlation Between Number of Patterns and Number of Network Parameters for elman_rnn linear 0.999831182075961

# %% [markdown]
#             # TOTOTOTOTOTODOODODODODOODODODO

# %% [markdown]
# ### Effect of sparsity length on training time

# %%
filter_col = "network_type"
    
plot_by_filter(x_col=filter_col_1, 
               y_col="epocs",
               x_label=x_label,
               y_label='Number of EPOCS required to train network',
               title="Effect of "+x_label+" on training time ", 
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)

# %% [markdown]
# ### Effect of sparsity length on training time for each activation

# %%
filter_col = "activation_function"
for filter_val in df[filter_col].unique():
    plot_by_filter(x_col=filter_col_1, 
                   y_col="epocs",
                   x_label=x_label,
                   y_label='Number of EPOCS required to train network',
                   title="Effect of "+x_label+" on training time " +
                           "\n for a neural network with activation " +str(filter_val), 
                   hue="network_type",
                  filter_col=filter_col, filter_val=filter_val, df=df)

# %% [markdown]
# ### Effect of sparsity on f-score

# %%
plot_by_filter(x_col="sparsity_length", 
               y_col="f_score",
               x_label=x_label,
               y_label='F1-score of the neural network',
               title="Effect of increase in "+x_label+" on the F1 score ",
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)

# %%
filter_col = "activation_function"
for filter_val in df[filter_col].unique():
    plot_by_filter(x_col="sparsity_length", 
               y_col="f_score",
               x_label=x_label,
               y_label='F1-score of the neural network',
               title="Effect of increase in "+x_label+" on the F1 score "+
                           "\n for neural network with activation " +str(filter_val), 
               hue="network_type",
              filter_col=filter_col, filter_val=filter_val, df=df)

# %% [markdown]
# ### Conclusion about capacity?

# %% [markdown]
# # Sparsity

# %%
df = pd.read_csv("sparsity.csv", delimiter=",")
df.head(5)

# %%
# plt.legend()
filter_col = "network_type"
    
plot_by_filter(x_col=x_col, 
               y_col="num_network_parameters",
               x_label=x_label,
               y_label='Number of network parameters',
               title="Effect of "+x_label+" on the number of parameters " + 
                       "\n in a neural network over all activation functions", 
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)   

plot_by_filter(x_col=x_col, 
               y_col="epocs",
               x_label=x_label,
               y_label='Number of EPOCS to train network',
               title="Effect of "+x_label+" on the number epocs required to train ",
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)  

plot_by_filter(x_col=x_col, 
               y_col="f_score",
               x_label=x_label,
               y_label='F1-score of the neural network',
               title="Effect of increase in "+x_label+" on the F1 score ",
               hue="network_type",
              filter_col=filter_col, filter_val=None, df=df)
