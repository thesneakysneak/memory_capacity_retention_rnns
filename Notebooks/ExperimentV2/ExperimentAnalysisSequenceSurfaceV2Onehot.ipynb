# %% [markdown]
# # Experiment Analysis Area Of Patterns Retained
# In this notebook we will evaluate the results form the experiments executed. For each experiment, one parameter is changed and all others were kept constant as to determine the effect of one variable.
#
# **The goals of this analysis are:**
# 1. Determine the relationship of the number of parameters in the neural network and Area of the patterns that can be retained
# 2. Investigate which activation function lead to the retention of Area
# 3. Determine what effect bidirectional RNNs has on this relationship
# 4. Determine the effect of increasing the number of layers has on Area retention

# %% [markdown]
# To determine whether a relationshop exists between the variable being investigated and the number of required parameters in each respective neural network, the Pearson correlation coefficient is used. The domain of this metric lies between -1 and +1 or in mathematical notation $P \in [-1, 1]$. If there exists a strong positive relationship between variables, the Pearson coefficient will approach +1 and for the negative case -1.

# %%
import pandas as pd 
import numpy as np
import scipy
import sklearn
import pandas as pd
from sqlalchemy import Column, Integer, String
from sqlalchemy import create_engine, Column
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Pattern Area Analysis

# %%
! wc -l /home/danielp/Documents/Masters/Code/memory_capacity_retention_rnns/danny_masters/100_0_False_volume_experiment.log
# Out:
# 411 /home/danielp/Documents/Masters/Code/memory_capacity_retention_rnns/danny_masters/100_0_False_volume_experiment.log

# %%
LSTM="lstm"
ELMAN_RNN="elman"
JORDAN_RNN="jordan"
GRU="gru"
BIDIRECTIONAL_RNN="bidirelamn"
BIDIRECTIONAL_LSTM="bidirlstm"
BIDIRECTIONAL_GRU="bidirgru"

def determine_model_parameters(row):
    nodes_in_layers = eval(row["nodes_in_layer"])
    nn_type = row["nn_type"]
    if nn_type == BIDIRECTIONAL_RNN:
        return sum(nodes_in_layers) * 6
    if nn_type == BIDIRECTIONAL_GRU:
        return sum(nodes_in_layers) * 21
    if nn_type == BIDIRECTIONAL_LSTM:
        return sum(nodes_in_layers) * 24
    if nn_type == LSTM:
        return sum(nodes_in_layers) *12
    if nn_type == GRU:
        return sum(nodes_in_layers) *9
    return sum(nodes_in_layers) * 3

# %%
df = pd.read_csv("/home/danielp/Documents/Masters/Code/memory_capacity_retention_rnns/danny_masters/from_server/100_0_True_volume_experiment.log", delimiter=";")
df["nn_type"] = df["nn_type"].apply(lambda x: x.replace("INFO:root:", "")) 
df["diff_small_large"] = df["smallest_not_retained"] - df["largest_retained"]
df["diff_small_large_len"] =  df["largest_len_retained"] - df["Unnamed: 6"]
df["model_params"] = df.apply(lambda row: determine_model_parameters(row), axis=1)
df["nodes_in_layer"] = df["nodes_in_layer"].apply(eval)
df["area"] = df["largest_retained"] * df["Unnamed: 6"]

# df = df[(df["diff_small_large"]  == 0) & (df["diff_small_large_len"]  == 1)]
df
# Out:
#      nn_type activation_func  parameters nodes_in_layer  largest_retained  smallest_not_retained  Unnamed: 6  largest_len_retained                          smallest_len_not_retained                                             status  model_params                                         num_epochs  model_score  highest_F1  diff_small_large  diff_small_large_len  area
# 0       lstm         softmax         504           [42]                 1                     12           8                     0  {'val_loss': [1.0013210773468018], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 1       lstm             elu         504           [42]                 1                     12           8                     0  {'val_loss': [0.877457320690155], 'loss': [0.9...                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 2       lstm             elu         504           [42]                 1                     14           8                     0  {'val_loss': [0.8857899308204651], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 3       lstm             elu         504           [42]                 1                     18           8                     0  {'val_loss': [0.6503276824951172], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 4       lstm             elu         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.6503276824951172], 'loss': [0....          1.0         NaN                 7                     0     8
# 5       lstm             elu         504           [42]                 2                     20           2                    11  {'val_loss': [0.4370969235897064, 0.4081567078...                                                0.5           504                                                NaN          NaN         NaN                18                     9     4
# 6       lstm             elu         504           [42]                 2                     21           2                     0  {'val_loss': [0.9092792570590973], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 7       lstm             elu         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a3...           504  {'val_loss': [0.9092792570590973], 'loss': [0....          1.0         NaN                 6                     1     2
# 8       lstm             elu         504           [42]                 4                     40           2                   699  {'val_loss': [0.4856029748916626, 0.4364235401...                                 0.5052083333333334           504                                                NaN          NaN         NaN                36                   697     8
# 9       lstm             elu         504           [42]                 4                     41           2                     0  {'val_loss': [0.9834126532077789], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 10      lstm             elu         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79e...           504  {'val_loss': [0.9834126532077789], 'loss': [1....          1.0         NaN                 4                     1     4
# 11      lstm             elu         504           [42]                 8                     80           2                   699  {'val_loss': [0.4362856596708298, 0.3741225153...                                  0.504585193452381           504                                                NaN          NaN         NaN                72                   697    16
# 12      lstm             elu         504           [42]                 8                     81           2                     0  {'val_loss': [0.9062802195549011], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 13      lstm             elu         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79e...           504  {'val_loss': [0.9062802195549011], 'loss': [0....          1.0         NaN                 0                     1     8
# 14      lstm            selu         504           [42]                 1                     12           8                     0  {'val_loss': [0.9338760375976562], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 15      lstm            selu         504           [42]                 1                     14           8                     0  {'val_loss': [0.6681516766548157], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 16      lstm            selu         504           [42]                 1                     18           8                     0  {'val_loss': [0.21687163412570953], 'loss': [0...                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 17      lstm            selu         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.21687163412570953], 'loss': [0...          1.0         NaN                 7                     0     8
# 18      lstm            selu         504           [42]                 2                     20           2                    29  {'val_loss': [0.39725619554519653, 0.334656655...                                                0.5           504                                                NaN          NaN         NaN                18                    27     4
# 19      lstm            selu         504           [42]                 2                     21           2                     0  {'val_loss': [0.7861810326576233], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 20      lstm            selu         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.7861810326576233], 'loss': [0....          1.0         NaN                 6                     1     2
# 21      lstm            selu         504           [42]                 4                     40           2                   699  {'val_loss': [0.3973252773284912, 0.3066962808...                                 0.5052083333333334           504                                                NaN          NaN         NaN                36                   697     8
# 22      lstm            selu         504           [42]                 4                     41           2                     0  {'val_loss': [0.6322805881500244], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 23      lstm            selu         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.6322805881500244], 'loss': [0....          1.0         NaN                 4                     1     4
# 24      lstm            selu         504           [42]                 8                     80           2                   103  {'val_loss': [0.39589133858680725, 0.272615507...                                 0.5061740451388889           504                                                NaN          NaN         NaN                72                   101    16
# 25      lstm            selu         504           [42]                 8                     81           2                     0  {'val_loss': [0.7590309381484985], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 26      lstm            selu         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.7590309381484985], 'loss': [0....          1.0         NaN                 0                     1     8
# 27      lstm        softplus         504           [42]                 1                     12           8                     0  {'val_loss': [0.10942476987838745], 'loss': [0...                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 28      lstm        softplus         504           [42]                 1                     14           8                     0  {'val_loss': [0.017952438443899155], 'loss': [...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 29      lstm        softplus         504           [42]                 1                     18           8                     0  {'val_loss': [0.03830079734325409], 'loss': [1...                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 30      lstm        softplus         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a3...           504  {'val_loss': [0.03830079734325409], 'loss': [1...          1.0         NaN                 7                     0     8
# 31      lstm        softplus         504           [42]                 2                     20           2                     0  {'val_loss': [0.6122974157333374], 'loss': [0....                                                0.5           504                                                NaN          NaN         NaN                18                    -2     4
# 32      lstm        softplus         504           [42]                 2                     21           2                     0  {'val_loss': [0.010119560174643993], 'loss': [...                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 33      lstm        softplus         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.010119560174643993], 'loss': [...          1.0         NaN                 6                     1     2
# 34      lstm        softplus         504           [42]                 4                     40           2                   699  {'val_loss': [0.33596283197402954, 0.208948910...                                                0.5           504                                                NaN          NaN         NaN                36                   697     8
# 35      lstm        softplus         504           [42]                 4                     41           2                     0  {'val_loss': [0.5589692294597626], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 36      lstm        softplus         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.5589692294597626], 'loss': [1....          1.0         NaN                 4                     1     4
# 37      lstm        softplus         504           [42]                 8                     80           2                   699  {'val_loss': [0.20231647044420242, 0.123806431...                                0.49545045882936506           504                                                NaN          NaN         NaN                72                   697    16
# 38      lstm        softplus         504           [42]                 8                     81           2                     0  {'val_loss': [0.6167832016944885], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 39      lstm        softplus         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.6167832016944885], 'loss': [1....          1.0         NaN                 0                     1     8
# 40      lstm        softsign         504           [42]                 1                     12           8                     0  {'val_loss': [0.8990627527236938], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 41      lstm        softsign         504           [42]                 1                     14           8                     0  {'val_loss': [0.7770504355430603], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 42      lstm        softsign         504           [42]                 1                     18           8                     0  {'val_loss': [0.8795070648193359], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 43      lstm        softsign         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f79e...           504  {'val_loss': [0.8795070648193359], 'loss': [1....          1.0         NaN                 7                     0     8
# 44      lstm        softsign         504           [42]                 2                     20           2                     2  {'val_loss': [0.46531103551387787, 0.441544666...                                                0.5           504                                                NaN          NaN         NaN                18                     0     4
# 45      lstm        softsign         504           [42]                 2                     21           2                     0  {'val_loss': [0.937985897064209], 'loss': [0.9...                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 46      lstm        softsign         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.937985897064209], 'loss': [0.9...          1.0         NaN                 6                     1     2
# 47      lstm        softsign         504           [42]                 4                     40           2                   699  {'val_loss': [0.42910490930080414, 0.389649093...                                 0.4895833333333333           504                                                NaN          NaN         NaN                36                   697     8
# 48      lstm        softsign         504           [42]                 4                     41           2                     0  {'val_loss': [0.9142566919326782], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 49      lstm        softsign         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79e...           504  {'val_loss': [0.9142566919326782], 'loss': [0....          1.0         NaN                 4                     1     4
# 50      lstm        softsign         504           [42]                 8                     80           2                   699  {'val_loss': [0.46202559769153595, 0.416008621...                                 0.4990606398809524           504                                                NaN          NaN         NaN                72                   697    16
# 51      lstm        softsign         504           [42]                 8                     81           2                     0  {'val_loss': [0.9007352590560913], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 52      lstm        softsign         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.9007352590560913], 'loss': [0....          1.0         NaN                 0                     1     8
# 53      lstm            tanh         504           [42]                 1                     12           8                     0  {'val_loss': [0.8728130459785461], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 54      lstm            tanh         504           [42]                 1                     14           8                     0  {'val_loss': [0.780285120010376], 'loss': [0.9...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 55      lstm            tanh         504           [42]                 1                     18           8                     0  {'val_loss': [0.8387290239334106], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 56      lstm            tanh         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a0...           504  {'val_loss': [0.8387290239334106], 'loss': [1....          1.0         NaN                 7                     0     8
# 57      lstm            tanh         504           [42]                 2                     20           2                     6  {'val_loss': [0.4684488922357559, 0.4344836175...                                                0.5           504                                                NaN          NaN         NaN                18                     4     4
# 58      lstm            tanh         504           [42]                 2                     21           2                     0  {'val_loss': [0.8972787261009216], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 59      lstm            tanh         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a5...           504  {'val_loss': [0.8972787261009216], 'loss': [0....          1.0         NaN                 6                     1     2
# 60      lstm            tanh         504           [42]                 4                     40           2                   699  {'val_loss': [0.4138997793197632, 0.3606670051...                                 0.5416666666666666           504                                                NaN          NaN         NaN                36                   697     8
# 61      lstm            tanh         504           [42]                 4                     41           2                     0  {'val_loss': [0.8747585415840149], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 62      lstm            tanh         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.8747585415840149], 'loss': [0....          1.0         NaN                 4                     1     4
# 63      lstm            tanh         504           [42]                 8                     80           2                   699  {'val_loss': [0.45873115956783295, 0.404470697...                                 0.5024088541666667           504                                                NaN          NaN         NaN                72                   697    16
# 64      lstm            tanh         504           [42]                 8                     81           2                     0  {'val_loss': [0.7839853763580322], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 65      lstm            tanh         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a0...           504  {'val_loss': [0.7839853763580322], 'loss': [0....          1.0         NaN                 0                     1     8
# 66      lstm         sigmoid         504           [42]                 1                     12           8                     0  {'val_loss': [0.5840998888015747], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 67      lstm         sigmoid         504           [42]                 1                     14           8                     0  {'val_loss': [0.39778369665145874], 'loss': [0...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 68      lstm         sigmoid         504           [42]                 1                     18           8                     0  {'val_loss': [0.3637908697128296], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 69      lstm         sigmoid         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a5...           504  {'val_loss': [0.3637908697128296], 'loss': [0....          1.0         NaN                 7                     0     8
# 70      lstm         sigmoid         504           [42]                 2                     20           2                    12  {'val_loss': [1.0536220073699951, 0.7932917177...                                                0.5           504                                                NaN          NaN         NaN                18                    10     4
# 71      lstm         sigmoid         504           [42]                 2                     21           2                     0  {'val_loss': [1.249024212360382], 'loss': [1.5...                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 72      lstm         sigmoid         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79b...           504  {'val_loss': [1.249024212360382], 'loss': [1.5...          1.0         NaN                 6                     1     2
# 73      lstm         sigmoid         504           [42]                 4                     40           2                   699  {'val_loss': [0.5534694790840149, 0.4069595336...                                                0.5           504                                                NaN          NaN         NaN                36                   697     8
# 74      lstm         sigmoid         504           [42]                 4                     41           2                     0  {'val_loss': [0.8610457181930542], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 75      lstm         sigmoid         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.8610457181930542], 'loss': [1....          1.0         NaN                 4                     1     4
# 76      lstm         sigmoid         504           [42]                 8                     80           2                   699  {'val_loss': [0.27971380949020386, 0.189140401...                                                0.5           504                                                NaN          NaN         NaN                72                   697    16
# 77      lstm         sigmoid         504           [42]                 8                     81           2                     0  {'val_loss': [1.0214651823043823], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 78      lstm         sigmoid         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a5...           504  {'val_loss': [1.0214651823043823], 'loss': [1....          1.0         NaN                 0                     1     8
# 79      lstm    hard_sigmoid         504           [42]                 1                     12           8                     0  {'val_loss': [0.396960973739624], 'loss': [0.5...                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 80      lstm    hard_sigmoid         504           [42]                 1                     14           8                     0  {'val_loss': [0.29493629932403564], 'loss': [0...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 81      lstm    hard_sigmoid         504           [42]                 1                     18           8                     0  {'val_loss': [0.013331887312233448], 'loss': [...                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 82      lstm    hard_sigmoid         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.013331887312233448], 'loss': [...          1.0         NaN                 7                     0     8
# 83      lstm    hard_sigmoid         504           [42]                 2                     20           2                   699  {'val_loss': [0.4493720978498459, 0.3554759323...                                                0.5           504                                                NaN          NaN         NaN                18                   697     4
# 84      lstm    hard_sigmoid         504           [42]                 2                     21           2                     0  {'val_loss': [0.32227422297000885], 'loss': [0...                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 85      lstm    hard_sigmoid         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f799...           504  {'val_loss': [0.32227422297000885], 'loss': [0...          1.0         NaN                 6                     1     2
# 86      lstm    hard_sigmoid         504           [42]                 4                     40           2                   699  {'val_loss': [0.3452645540237427, 0.2570234686...                                                0.5           504                                                NaN          NaN         NaN                36                   697     8
# 87      lstm    hard_sigmoid         504           [42]                 4                     41           2                     0  {'val_loss': [0.6802210807800293], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 88      lstm    hard_sigmoid         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a5...           504  {'val_loss': [0.6802210807800293], 'loss': [0....          1.0         NaN                 4                     1     4
# 89      lstm    hard_sigmoid         504           [42]                 8                     80           2                   699  {'val_loss': [0.5051329731941223, 0.3513894677...                                                0.5           504                                                NaN          NaN         NaN                72                   697    16
# 90      lstm    hard_sigmoid         504           [42]                 8                     81           2                     0  {'val_loss': [0.5724099576473236], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 91      lstm    hard_sigmoid         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f799...           504  {'val_loss': [0.5724099576473236], 'loss': [0....          1.0         NaN                 0                     1     8
# 92      lstm            relu         504           [42]                 1                     12           8                     0  {'val_loss': [0.9400044679641724], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 93      lstm            relu         504           [42]                 1                     14           8                     0  {'val_loss': [1.019726276397705], 'loss': [1.0...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 94      lstm            relu         504           [42]                 1                     18           8                     0  {'val_loss': [0.8368062376976013], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 95      lstm            relu         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a5...           504  {'val_loss': [0.8368062376976013], 'loss': [0....          1.0         NaN                 7                     0     8
# 96      lstm            relu         504           [42]                 2                     20           2                    45  {'val_loss': [0.4823053479194641, 0.4649053215...                                                0.5           504                                                NaN          NaN         NaN                18                    43     4
# 97      lstm            relu         504           [42]                 2                     21           2                     0  {'val_loss': [0.9368155002593994], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 98      lstm            relu         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.9368155002593994], 'loss': [0....          1.0         NaN                 6                     1     2
# 99      lstm            relu         504           [42]                 4                     40           2                   699  {'val_loss': [0.4904250204563141, 0.4695261567...                                 0.4947916666666667           504                                                NaN          NaN         NaN                36                   697     8
# 100     lstm            relu         504           [42]                 4                     41           2                     0  {'val_loss': [0.8384601175785065], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 101     lstm            relu         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a0...           504  {'val_loss': [0.8384601175785065], 'loss': [0....          1.0         NaN                 4                     1     4
# 102     lstm            relu         504           [42]                 8                     80           2                   699  {'val_loss': [0.4852382391691208, 0.4523592293...                                 0.4984824528769841           504                                                NaN          NaN         NaN                72                   697    16
# 103     lstm            relu         504           [42]                 8                     81           2                     0  {'val_loss': [0.9233355820178986], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 104     lstm            relu         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a3...           504  {'val_loss': [0.9233355820178986], 'loss': [0....          1.0         NaN                 0                     1     8
# 105     lstm          linear         504           [42]                 1                     12           8                     0  {'val_loss': [0.9048642516136169], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 106     lstm          linear         504           [42]                 1                     14           8                     0  {'val_loss': [0.78108149766922], 'loss': [0.90...                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 107     lstm          linear         504           [42]                 1                     18           8                     0  {'val_loss': [0.6168227195739746], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 108     lstm          linear         504           [42]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a6...           504  {'val_loss': [0.6168227195739746], 'loss': [0....          1.0         NaN                 7                     0     8
# 109     lstm          linear         504           [42]                 2                     20           2                     5  {'val_loss': [0.43607111275196075, 0.406540289...                                                0.5           504                                                NaN          NaN         NaN                18                     3     4
# 110     lstm          linear         504           [42]                 2                     21           2                     0  {'val_loss': [0.9482200145721436], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 111     lstm          linear         504           [42]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79e...           504  {'val_loss': [0.9482200145721436], 'loss': [1....          1.0         NaN                 6                     1     2
# 112     lstm          linear         504           [42]                 4                     40           2                   699  {'val_loss': [0.4469236731529236, 0.3823062181...                                 0.5052083333333334           504                                                NaN          NaN         NaN                36                   697     8
# 113     lstm          linear         504           [42]                 4                     41           2                     0  {'val_loss': [0.816620409488678], 'loss': [0.8...                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 114     lstm          linear         504           [42]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a3...           504  {'val_loss': [0.816620409488678], 'loss': [0.8...          1.0         NaN                 4                     1     4
# 115     lstm          linear         504           [42]                 8                     80           2                   699  {'val_loss': [0.4345666617155075, 0.3618326634...                                0.49372984871031744           504                                                NaN          NaN         NaN                72                   697    16
# 116     lstm          linear         504           [42]                 8                     81           2                     0  {'val_loss': [0.81704181432724], 'loss': [0.89...                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 117     lstm          linear         504           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79b...           504  {'val_loss': [0.81704181432724], 'loss': [0.89...          1.0         NaN                 0                     1     8
# 118      gru         softmax         504           [56]                 1                     12           8                     0  {'val_loss': [0.9527060985565186], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                11                    -8     8
# 119      gru         softmax         504           [56]                 1                     14           8                     0  {'val_loss': [1.0476778745651245], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                13                    -8     8
# 120      gru         softmax         504           [56]                 1                     18           8                     0  {'val_loss': [0.9724186658859253], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                17                    -8     8
# 121      gru         softmax         504           [56]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a1...           504  {'val_loss': [0.9724186658859253], 'loss': [0....          1.0         NaN                 7                     0     8
# 122      gru         softmax         504           [56]                 2                     20           2                   699  {'val_loss': [0.48777884244918823, 0.474766820...                                                0.5           504                                                NaN          NaN         NaN                18                   697     4
# 123      gru         softmax         504           [56]                 2                     21           2                     0  {'val_loss': [0.9905482232570648], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                19                    -2     4
# 124      gru         softmax         504           [56]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a3...           504  {'val_loss': [0.9905482232570648], 'loss': [1....          1.0         NaN                 6                     1     2
# 125      gru         softmax         504           [56]                 4                     40           2                   699  {'val_loss': [0.48070859909057617, 0.465578883...                                                0.5           504                                                NaN          NaN         NaN                36                   697     8
# 126      gru         softmax         504           [56]                 4                     41           2                     0  {'val_loss': [0.9511893093585968], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                37                    -2     8
# 127      gru         softmax         504           [56]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79b...           504  {'val_loss': [0.9511893093585968], 'loss': [0....          1.0         NaN                 4                     1     4
# 128      gru         softmax         504           [56]                 8                     80           2                   699  {'val_loss': [0.48443061113357544, 0.468730986...                                                0.5           504                                                NaN          NaN         NaN                72                   697    16
# ...
# 4890     gru    hard_sigmoid        3528          [392]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a0...          3528  {'val_loss': [0.2148832231760025], 'loss': [0....          1.0         NaN                 6                     1     2
# 4891     gru    hard_sigmoid        3528          [392]                 4                     40           2                   699  {'val_loss': [0.48108629882335663, 0.201105788...                                                0.5          3528                                                NaN          NaN         NaN                36                   697     8
# 4892     gru    hard_sigmoid        3528          [392]                 4                     41           2                     0  {'val_loss': [0.33959904313087463], 'loss': [0...                                                1.0          3528                                                NaN          NaN         NaN                37                    -2     8
# 4893     gru    hard_sigmoid        3528          [392]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...          3528  {'val_loss': [0.33959904313087463], 'loss': [0...          1.0         NaN                 4                     1     4
# 4894     gru    hard_sigmoid        3528          [392]                 8                     80           2                   699  {'val_loss': [0.2286224663257599, 0.1187671646...                                 0.4850492931547619          3528                                                NaN          NaN         NaN                72                   697    16
# 4895     gru    hard_sigmoid        3528          [392]                 8                     81           2                     0  {'val_loss': [0.2559468746185303], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                73                    -2    16
# 4896     gru    hard_sigmoid        3528          [392]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a3...          3528  {'val_loss': [0.2559468746185303], 'loss': [0....          1.0         NaN                 0                     1     8
# 4897     gru            relu        3528          [392]                 1                     12           8                     0  {'val_loss': [0.6901049613952637], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                11                    -8     8
# 4898     gru            relu        3528          [392]                 1                     14           8                     0  {'val_loss': [0.5138378143310547], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                13                    -8     8
# 4899     gru            relu        3528          [392]                 1                     18           8                     0  {'val_loss': [0.43377935886383057], 'loss': [0...                                                1.0          3528                                                NaN          NaN         NaN                17                    -8     8
# 4900     gru            relu        3528          [392]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a1...          3528  {'val_loss': [0.43377935886383057], 'loss': [0...          1.0         NaN                 7                     0     8
# 4901     gru            relu        3528          [392]                 2                     20           2                     3  {'val_loss': [0.4265623539686203, 0.3321675658...                                                0.5          3528                                                NaN          NaN         NaN                18                     1     4
# 4902     gru            relu        3528          [392]                 2                     21           2                     0  {'val_loss': [0.7141053676605225], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                19                    -2     4
# 4903     gru            relu        3528          [392]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a5...          3528  {'val_loss': [0.7141053676605225], 'loss': [0....          1.0         NaN                 6                     1     2
# 4904     gru            relu        3528          [392]                 4                     40           2                   699  {'val_loss': [0.36145035922527313, 0.199843503...                                 0.4583333333333333          3528                                                NaN          NaN         NaN                36                   697     8
# 4905     gru            relu        3528          [392]                 4                     41           2                     0  {'val_loss': [0.7585179507732391], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                37                    -2     8
# 4906     gru            relu        3528          [392]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79b...          3528  {'val_loss': [0.7585179507732391], 'loss': [0....          1.0         NaN                 4                     1     4
# 4907     gru            relu        3528          [392]                 8                     80           2                   699  {'val_loss': [0.3545786291360855, 0.1811075136...                                 0.5006370907738096          3528                                                NaN          NaN         NaN                72                   697    16
# 4908     gru            relu        3528          [392]                 8                     81           2                     0  {'val_loss': [0.6645200252532959], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                73                    -2    16
# 4909     gru            relu        3528          [392]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a5...          3528  {'val_loss': [0.6645200252532959], 'loss': [0....          1.0         NaN                 0                     1     8
# 4910     gru          linear        3528          [392]                 1                     12           8                     0  {'val_loss': [0.2740548849105835], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                11                    -8     8
# 4911     gru          linear        3528          [392]                 1                     14           8                     0  {'val_loss': [0.022864557802677155], 'loss': [...                                                1.0          3528                                                NaN          NaN         NaN                13                    -8     8
# 4912     gru          linear        3528          [392]                 1                     18           8                     0  {'val_loss': [0.13066813349723816], 'loss': [0...                                                1.0          3528                                                NaN          NaN         NaN                17                    -8     8
# 4913     gru          linear        3528          [392]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f7a5...          3528  {'val_loss': [0.13066813349723816], 'loss': [0...          1.0         NaN                 7                     0     8
# 4914     gru          linear        3528          [392]                 2                     20           2                     6  {'val_loss': [0.3206645995378494, 0.3102170899...                                                0.5          3528                                                NaN          NaN         NaN                18                     4     4
# 4915     gru          linear        3528          [392]                 2                     21           2                     0  {'val_loss': [0.5011523067951202], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                19                    -2     4
# 4916     gru          linear        3528          [392]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...          3528  {'val_loss': [0.5011523067951202], 'loss': [0....          1.0         NaN                 6                     1     2
# 4917     gru          linear        3528          [392]                 4                     40           2                   699  {'val_loss': [0.2046937718987465, 0.1884348466...                                 0.4739583333333333          3528                                                NaN          NaN         NaN                36                   697     8
# 4918     gru          linear        3528          [392]                 4                     41           2                     0  {'val_loss': [0.2682048827409744], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                37                    -2     8
# 4919     gru          linear        3528          [392]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...          3528  {'val_loss': [0.2682048827409744], 'loss': [0....          1.0         NaN                 4                     1     4
# 4920     gru          linear        3528          [392]                 8                     80           2                   699  {'val_loss': [0.1324952319264412, 0.1408085525...                                 0.5024290054563492          3528                                                NaN          NaN         NaN                72                   697    16
# 4921     gru          linear        3528          [392]                 8                     81           2                     0  {'val_loss': [0.06020652689039707], 'loss': [0...                                                1.0          3528                                                NaN          NaN         NaN                73                    -2    16
# 4922     gru          linear        3528          [392]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...          3528  {'val_loss': [0.06020652689039707], 'loss': [0...          1.0         NaN                 0                     1     8
# 4923   elman         softmax        3528         [1176]                 1                     12           8                     0  {'val_loss': [0.9678082466125488], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                11                    -8     8
# 4924   elman         softmax        3528         [1176]                 1                     14           8                     0  {'val_loss': [0.9667837619781494], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                13                    -8     8
# 4925   elman         softmax        3528         [1176]                 1                     18           8                     0  {'val_loss': [0.9700911641120911], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                17                    -8     8
# 4926   elman         softmax        3528         [1176]                 1                      8           8                     8                                              found  <keras.engine.training.Model object at 0x7f79b...          3528  {'val_loss': [0.9700911641120911], 'loss': [0....          1.0         NaN                 7                     0     8
# 4927   elman         softmax        3528         [1176]                 2                     20           2                     0  {'val_loss': [0.4865957498550415], 'loss': [0....                                                0.5          3528                                                NaN          NaN         NaN                18                    -2     4
# 4928   elman         softmax        3528         [1176]                 2                     21           2                     0  {'val_loss': [0.9651277661323547], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                19                    -2     4
# 4929   elman         softmax        3528         [1176]                 2                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f79b...          3528  {'val_loss': [0.9651277661323547], 'loss': [0....          1.0         NaN                 6                     1     2
# 4930   elman         softmax        3528         [1176]                 4                     40           2                   699  {'val_loss': [0.4839319586753845, 0.4689406454...                                                0.5          3528                                                NaN          NaN         NaN                36                   697     8
# 4931   elman         softmax        3528         [1176]                 4                     41           2                     0  {'val_loss': [0.9677748084068298], 'loss': [0....                                                1.0          3528                                                NaN          NaN         NaN                37                    -2     8
# 4932   elman         softmax        3528         [1176]                 4                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7f7a6...          3528  {'val_loss': [0.9677748084068298], 'loss': [0....          1.0         NaN                 4                     1     4
#
# [4933 rows x 17 columns]

# %%
df[(df["nn_type"] == "bidirlstm") & (df[(df["nn_type"] == "bidirlstm")]["largest_retained"] == df[(df["nn_type"] == "bidirlstm")]["largest_retained"].max())]
# Out:
#         nn_type activation_func  parameters nodes_in_layer  largest_retained  smallest_not_retained  Unnamed: 6  largest_len_retained                          smallest_len_not_retained                                             status  model_params                                         num_epochs  model_score  highest_F1  diff_small_large  diff_small_large_len  area
# 533   bidirlstm         softmax         504           [21]                 8                     80           2                   699  {'val_loss': [1.3326675295829773, 1.2966076135...                                0.29059089781746034           504                                                NaN          NaN         NaN                72                   697    16
# 534   bidirlstm         softmax         504           [21]                 8                     81           2                     0  {'val_loss': [0.9789214134216309], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 535   bidirlstm         softmax         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...           504  {'val_loss': [0.9789214134216309], 'loss': [0....          1.0         NaN                 0                     1     8
# 546   bidirlstm             elu         504           [21]                 8                     80           2                   699  {'val_loss': [1.207161784172058, 1.05773109197...                                 0.5574404761904762           504                                                NaN          NaN         NaN                72                   697    16
# 547   bidirlstm             elu         504           [21]                 8                     81           2                     0  {'val_loss': [0.9080487191677094], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 548   bidirlstm             elu         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...           504  {'val_loss': [0.9080487191677094], 'loss': [0....          1.0         NaN                 0                     1     8
# 560   bidirlstm            selu         504           [21]                 8                     80           2                   699  {'val_loss': [0.8657066226005554, 0.5731668770...                                 0.5575799851190476           504                                                NaN          NaN         NaN                72                   697    16
# 561   bidirlstm            selu         504           [21]                 8                     81           2                     0  {'val_loss': [0.6765260100364685], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 562   bidirlstm            selu         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb2...           504  {'val_loss': [0.6765260100364685], 'loss': [0....          1.0         NaN                 0                     1     8
# 573   bidirlstm        softplus         504           [21]                 8                     80           2                   699  {'val_loss': [2.097662091255188, 0.92740330100...                                0.26552269345238094           504                                                NaN          NaN         NaN                72                   697    16
# 574   bidirlstm        softplus         504           [21]                 8                     81           2                     0  {'val_loss': [1.2189202904701233], 'loss': [1....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 575   bidirlstm        softplus         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...           504  {'val_loss': [1.2189202904701233], 'loss': [1....          1.0         NaN                 0                     1     8
# 586   bidirlstm        softsign         504           [21]                 8                     80           2                   699  {'val_loss': [1.3341288566589355, 1.2197294235...                                 0.5555090525793651           504                                                NaN          NaN         NaN                72                   697    16
# 587   bidirlstm        softsign         504           [21]                 8                     81           2                     0  {'val_loss': [0.8591031730175018], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 588   bidirlstm        softsign         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbae...           504  {'val_loss': [0.8591031730175018], 'loss': [0....          1.0         NaN                 0                     1     8
# 599   bidirlstm            tanh         504           [21]                 8                     80           2                   699  {'val_loss': [1.3481023907661438, 1.1710604429...                                 0.5588572668650794           504                                                NaN          NaN         NaN                72                   697    16
# 600   bidirlstm            tanh         504           [21]                 8                     81           2                     0  {'val_loss': [0.9138502776622772], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 601   bidirlstm            tanh         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...           504  {'val_loss': [0.9138502776622772], 'loss': [0....          1.0         NaN                 0                     1     8
# 612   bidirlstm         sigmoid         504           [21]                 8                     80           2                   699  {'val_loss': [0.9819387793540955, 0.7399297356...                                 0.3935174851190476           504                                                NaN          NaN         NaN                72                   697    16
# 613   bidirlstm         sigmoid         504           [21]                 8                     81           2                     0  {'val_loss': [0.5464411079883575], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 614   bidirlstm         sigmoid         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbae...           504  {'val_loss': [0.5464411079883575], 'loss': [0....          1.0         NaN                 0                     1     8
# 625   bidirlstm    hard_sigmoid         504           [21]                 8                     80           2                   699  {'val_loss': [0.7635362446308136, 0.5557866096...                                0.27688182043650794           504                                                NaN          NaN         NaN                72                   697    16
# 626   bidirlstm    hard_sigmoid         504           [21]                 8                     81           2                     0  {'val_loss': [0.7576219439506531], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 627   bidirlstm    hard_sigmoid         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbc0...           504  {'val_loss': [0.7576219439506531], 'loss': [0....          1.0         NaN                 0                     1     8
# 638   bidirlstm            relu         504           [21]                 8                     80           2                   699  {'val_loss': [1.3337443470954895, 1.2549241185...                                 0.5676494295634921           504                                                NaN          NaN         NaN                72                   697    16
# 639   bidirlstm            relu         504           [21]                 8                     81           2                     0  {'val_loss': [0.9151507914066315], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 640   bidirlstm            relu         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...           504  {'val_loss': [0.9151507914066315], 'loss': [0....          1.0         NaN                 0                     1     8
# 651   bidirlstm          linear         504           [21]                 8                     80           2                   699  {'val_loss': [1.3171016573905945, 1.1672392487...                                 0.5523530505952381           504                                                NaN          NaN         NaN                72                   697    16
# 652   bidirlstm          linear         504           [21]                 8                     81           2                     0  {'val_loss': [0.8718019127845764], 'loss': [0....                                                1.0           504                                                NaN          NaN         NaN                73                    -2    16
# 653   bidirlstm          linear         504           [21]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...           504  {'val_loss': [0.8718019127845764], 'loss': [0....          1.0         NaN                 0                     1     8
# 1337  bidirlstm         softmax        1008           [42]                 8                     80           2                   699  {'val_loss': [1.3430160284042358, 1.3071070313...                                              0.125          1008                                                NaN          NaN         NaN                72                   697    16
# 1338  bidirlstm         softmax        1008           [42]                 8                     81           2                     0  {'val_loss': [0.9724691808223724], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1339  bidirlstm         softmax        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...          1008  {'val_loss': [0.9724691808223724], 'loss': [0....          1.0         NaN                 0                     1     8
# 1350  bidirlstm             elu        1008           [42]                 8                     80           2                   699  {'val_loss': [1.1757861971855164, 0.9259132742...                                 0.5680989583333333          1008                                                NaN          NaN         NaN                72                   697    16
# 1351  bidirlstm             elu        1008           [42]                 8                     81           2                     0  {'val_loss': [0.8416996598243713], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1352  bidirlstm             elu        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb2...          1008  {'val_loss': [0.8416996598243713], 'loss': [0....          1.0         NaN                 0                     1     8
# 1364  bidirlstm            selu        1008           [42]                 8                     80           2                   699  {'val_loss': [0.7320706248283386, 0.1987648382...                                  0.558820064484127          1008                                                NaN          NaN         NaN                72                   697    16
# 1365  bidirlstm            selu        1008           [42]                 8                     81           2                     0  {'val_loss': [0.5452224910259247], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1366  bidirlstm            selu        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb4...          1008  {'val_loss': [0.5452224910259247], 'loss': [0....          1.0         NaN                 0                     1     8
# 1378  bidirlstm        softplus        1008           [42]                 8                     80           2                   699  {'val_loss': [0.13861704617738724, 0.198590762...                                  0.275421626984127          1008                                                NaN          NaN         NaN                72                   697    16
# 1379  bidirlstm        softplus        1008           [42]                 8                     81           2                     0  {'val_loss': [0.055375296622514725], 'loss': [...                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1380  bidirlstm        softplus        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb2...          1008  {'val_loss': [0.055375296622514725], 'loss': [...          1.0         NaN                 0                     1     8
# 1391  bidirlstm        softsign        1008           [42]                 8                     80           2                   699  {'val_loss': [1.2690300941467285, 1.0987173914...                                 0.5612072172619048          1008                                                NaN          NaN         NaN                72                   697    16
# 1392  bidirlstm        softsign        1008           [42]                 8                     81           2                     0  {'val_loss': [0.746253490447998], 'loss': [0.8...                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1393  bidirlstm        softsign        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...          1008  {'val_loss': [0.746253490447998], 'loss': [0.8...          1.0         NaN                 0                     1     8
# 1405  bidirlstm            tanh        1008           [42]                 8                     80           2                   699  {'val_loss': [1.1496586203575134, 0.8994850516...                                 0.5580140128968254          1008                                                NaN          NaN         NaN                72                   697    16
# 1406  bidirlstm            tanh        1008           [42]                 8                     81           2                     0  {'val_loss': [0.8408581614494324], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1407  bidirlstm            tanh        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1008  {'val_loss': [0.8408581614494324], 'loss': [0....          1.0         NaN                 0                     1     8
# 1418  bidirlstm         sigmoid        1008           [42]                 8                     80           2                   699  {'val_loss': [1.4594794511795044, 0.8026605844...                                0.27503720238095236          1008                                                NaN          NaN         NaN                72                   697    16
# 1419  bidirlstm         sigmoid        1008           [42]                 8                     81           2                     0  {'val_loss': [0.7122979760169983], 'loss': [1....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1420  bidirlstm         sigmoid        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1008  {'val_loss': [0.7122979760169983], 'loss': [1....          1.0         NaN                 0                     1     8
# 1431  bidirlstm    hard_sigmoid        1008           [42]                 8                     80           2                   699  {'val_loss': [0.9533549845218658, 0.4990542232...                                 0.5230902777777777          1008                                                NaN          NaN         NaN                72                   697    16
# 1432  bidirlstm    hard_sigmoid        1008           [42]                 8                     81           2                     0  {'val_loss': [0.29064102470874786], 'loss': [0...                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1433  bidirlstm    hard_sigmoid        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbc0...          1008  {'val_loss': [0.29064102470874786], 'loss': [0...          1.0         NaN                 0                     1     8
# 1444  bidirlstm            relu        1008           [42]                 8                     80           2                   699  {'val_loss': [1.2787360548973083, 1.1384564042...                                 0.5568111359126984          1008                                                NaN          NaN         NaN                72                   697    16
# 1445  bidirlstm            relu        1008           [42]                 8                     81           2                     0  {'val_loss': [0.8924855589866638], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1446  bidirlstm            relu        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb2...          1008  {'val_loss': [0.8924855589866638], 'loss': [0....          1.0         NaN                 0                     1     8
# 1458  bidirlstm          linear        1008           [42]                 8                     80           2                   699  {'val_loss': [1.1598726511001587, 0.9112340211...                                 0.5605995783730159          1008                                                NaN          NaN         NaN                72                   697    16
# 1459  bidirlstm          linear        1008           [42]                 8                     81           2                     0  {'val_loss': [0.8043641149997711], 'loss': [0....                                                1.0          1008                                                NaN          NaN         NaN                73                    -2    16
# 1460  bidirlstm          linear        1008           [42]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbae...          1008  {'val_loss': [0.8043641149997711], 'loss': [0....          1.0         NaN                 0                     1     8
# 2149  bidirlstm         softmax        1512           [63]                 8                     80           2                   699  {'val_loss': [1.35732102394104, 1.321393430233...                                              0.125          1512                                                NaN          NaN         NaN                72                   697    16
# 2150  bidirlstm         softmax        1512           [63]                 8                     81           2                     0  {'val_loss': [0.9756632745265961], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2151  bidirlstm         softmax        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...          1512  {'val_loss': [0.9756632745265961], 'loss': [0....          1.0         NaN                 0                     1     8
# 2163  bidirlstm             elu        1512           [63]                 8                     80           2                   699  {'val_loss': [1.0736708641052246, 0.6772988140...                                 0.5272166418650793          1512                                                NaN          NaN         NaN                72                   697    16
# 2164  bidirlstm             elu        1512           [63]                 8                     81           2                     0  {'val_loss': [0.7594628632068634], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2165  bidirlstm             elu        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbaa...          1512  {'val_loss': [0.7594628632068634], 'loss': [0....          1.0         NaN                 0                     1     8
# 2177  bidirlstm            selu        1512           [63]                 8                     80           2                   699  {'val_loss': [0.44885702431201935, 0.203446082...                                 0.4112630208333333          1512                                                NaN          NaN         NaN                72                   697    16
# 2178  bidirlstm            selu        1512           [63]                 8                     81           2                     0  {'val_loss': [0.32651200890541077], 'loss': [0...                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2179  bidirlstm            selu        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb4...          1512  {'val_loss': [0.32651200890541077], 'loss': [0...          1.0         NaN                 0                     1     8
# 2190  bidirlstm        softplus        1512           [63]                 8                     80           2                   699  {'val_loss': [0.34455281496047974, 0.125935055...                                 0.5343036954365079          1512                                                NaN          NaN         NaN                72                   697    16
# 2191  bidirlstm        softplus        1512           [63]                 8                     81           2                     0  {'val_loss': [0.20928654819726944], 'loss': [0...                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2192  bidirlstm        softplus        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1512  {'val_loss': [0.20928654819726944], 'loss': [0...          1.0         NaN                 0                     1     8
# 2203  bidirlstm        softsign        1512           [63]                 8                     80           2                   699  {'val_loss': [1.0942043662071228, 0.8079400062...                                 0.5672588045634921          1512                                                NaN          NaN         NaN                72                   697    16
# 2204  bidirlstm        softsign        1512           [63]                 8                     81           2                     0  {'val_loss': [0.7866544425487518], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2205  bidirlstm        softsign        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb4...          1512  {'val_loss': [0.7866544425487518], 'loss': [0....          1.0         NaN                 0                     1     8
# 2216  bidirlstm            tanh        1512           [63]                 8                     80           2                   699  {'val_loss': [1.0730909705162048, 0.6626840531...                                 0.5596044146825396          1512                                                NaN          NaN         NaN                72                   697    16
# 2217  bidirlstm            tanh        1512           [63]                 8                     81           2                     0  {'val_loss': [0.6657269299030304], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2218  bidirlstm            tanh        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb8...          1512  {'val_loss': [0.6657269299030304], 'loss': [0....          1.0         NaN                 0                     1     8
# 2229  bidirlstm         sigmoid        1512           [63]                 8                     80           2                   699  {'val_loss': [0.5190941989421844, 0.1323039680...                                0.26138702876984127          1512                                                NaN          NaN         NaN                72                   697    16
# 2230  bidirlstm         sigmoid        1512           [63]                 8                     81           2                     0  {'val_loss': [0.4287789314985275], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2231  bidirlstm         sigmoid        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1512  {'val_loss': [0.4287789314985275], 'loss': [0....          1.0         NaN                 0                     1     8
# 2242  bidirlstm    hard_sigmoid        1512           [63]                 8                     80           2                   699  {'val_loss': [1.0477661490440369, 0.3915289044...                                 0.5225074404761905          1512                                                NaN          NaN         NaN                72                   697    16
# 2243  bidirlstm    hard_sigmoid        1512           [63]                 8                     81           2                     0  {'val_loss': [0.2720817029476166], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2244  bidirlstm    hard_sigmoid        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb2...          1512  {'val_loss': [0.2720817029476166], 'loss': [0....          1.0         NaN                 0                     1     8
# 2256  bidirlstm            relu        1512           [63]                 8                     80           2                   699  {'val_loss': [1.274402916431427, 1.10785967111...                                 0.5499100942460318          1512                                                NaN          NaN         NaN                72                   697    16
# 2257  bidirlstm            relu        1512           [63]                 8                     81           2                     0  {'val_loss': [0.8637963533401489], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2258  bidirlstm            relu        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1512  {'val_loss': [0.8637963533401489], 'loss': [0....          1.0         NaN                 0                     1     8
# 2269  bidirlstm          linear        1512           [63]                 8                     80           2                   699  {'val_loss': [1.053768277168274, 0.62097209692...                                 0.5572296626984127          1512                                                NaN          NaN         NaN                72                   697    16
# 2270  bidirlstm          linear        1512           [63]                 8                     81           2                     0  {'val_loss': [0.8171221315860748], 'loss': [0....                                                1.0          1512                                                NaN          NaN         NaN                73                    -2    16
# 2271  bidirlstm          linear        1512           [63]                 8                      8           1                     2                                              found  <keras.engine.training.Model object at 0x7fbb0...          1512  {'val_loss': [0.8171221315860748], 'loss': [0....          1.0         NaN                 0                     1     8

# %% [markdown]
# ## 1. Number of parameters $\varpropto$ pattern length
# #### Relationship of the number of parameters in network to length of patterns retained

# %% [markdown]
# ### Overall

# %%
from matplotlib import pyplot


def get_cmap(n, name='hsv'):
    import matplotlib.pyplot as plt
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

def plot_line_sub_plots(df, x="num_layers", y="largest_retained", hue="activation_func",
                        x_label="num_layers", y_label="largest_retained", legend_loc='upper left'):
    import numpy as np
    import matplotlib.pyplot as plt
    unique_hue = df[hue].unique().tolist()
    n_rows = (int)(np.ceil(len(unique_hue)/2))
    fig, ax = plt.subplots(nrows=n_rows, ncols=2, sharex=True, sharey=True, constrained_layout=True)
    fig.set_size_inches(20, 4*n_rows)
    
    cmap = get_cmap(len(unique_hue))
    row_c = 0
    col_c = 0
    index = 0
    for row_c in range(n_rows):
        for col_c in range(2):
            if index > len(unique_hue) - 1:
                break
            ax[row_c][col_c].set_xlabel(x_label, fontsize=15)
            ax[row_c][col_c].set_ylabel(y_label, fontsize=15)
            ax[row_c][col_c].legend([unique_hue[index]])
            
            df_temp = df[df[hue] == unique_hue[index]]
            ax[row_c][col_c].plot(df_temp[x], df_temp[y], label=unique_hue[index], marker='o', 
                                  linewidth=2, markersize=12, color=cmap(index))

            legend = ax[row_c][col_c].legend(loc=legend_loc, shadow=False, fontsize=15)
            
            index += 1
        # Put a nicer background color on the legend.
        # legend.get_frame().set_facecolor('C0')
    
    plt.show()
    return fig
    
    
def plot_by_filter(x_col, 
                   y_col, 
                   x_label='Sparsity length',
                   y_label='Number of network parameters',
                   title="Effect of sparsity on the number of parameters \n in a neural network with activation ", 
                   hue="network_type",
                   filter_col="activation_function", 
                   filter_val="tanh",
                   legend_title="NN TYPE",
                  df=None):
    sns.set_style("whitegrid")
    a4_dims = (12, 4.5)
    fig, ax = pyplot.subplots(figsize=a4_dims)
    ax.set(xlabel=x_label, 
       ylabel=y_label )
    if filter_val is not None:
        ax = sns.pointplot(ax=ax, x=x_col, y=y_col, hue=hue, 
                          marker='o',  linestyle='-', markersize=5, ci=None,
                          data = df[df[filter_col] == filter_val])
       
        ax.axes.set_title(title + filter_val,
                          fontsize=12, y=1.05)
        ax.set(xlabel=x_label, 
       ylabel=y_label )
        ax.legend(title=filter_val.upper(), loc='left', bbox_to_anchor=(1.37, 0.5), ncol=1)
    else:
        ax = sns.pointplot(ax=ax, x=x_col, y=y_col, hue=hue, 
                          marker='o',   linestyle='-', markersize=5, ci=None,
                          data = df)
        ax.axes.set_title(title, fontsize=12, y=1.05)
        ax.set(xlabel=x_label, 
       ylabel=y_label )
        ax.legend(title=legend_title, loc='center right', bbox_to_anchor=(1.37, 0.5), ncol=1)

    # plt.legend()
filter_col = "nn_type"
filter_1 = "area"
x_col = "area"
x_label = "Area of Patterns"
plot_by_filter(x_col=x_col, 
               y_col="model_params",
               x_label="Area of pattern retained",
               y_label='Number of network parameters',
               title="Effect of the number of parameters on the ability recognise area patterns" + 
                       "\n in a neural network over all activation functions", 
               hue="nn_type",
              filter_col=filter_col, filter_val=None, df=df)

# %%
df_g = df.groupby(["nn_type", "model_params"]).agg({"area" : "mean"}).reset_index()
fig = plot_line_sub_plots(df_g, 
            x="model_params", y="area", hue="nn_type",
            x_label='Number of Parameters in Model', y_label='Average Area \n of Patterns retained')
fig.savefig("Images/AreaPatternsVsParametersRNN_exp3_2.pdf", bbox_inches='tight')

# %% [markdown]
# ### Correlation

# %%
x_col = "area"
filter_col = "nn_type"
filter_col_1 = x_col
x_label = "Number of Patterns"
for filter_val in df[filter_col].unique():
    df_temp = df[df[filter_col] == filter_val]
    df_temp = df_temp.groupby([x_col, "nn_type"]).agg({"model_params": "mean"}).to_records()
    df_temp = pd.DataFrame.from_records(df_temp)
    df_temp[x_col] = df_temp[x_col].astype(float)
    df_temp["model_params"] = df_temp["model_params"].astype(float)
    df_temp.dropna(inplace=True)
    print("Spearman Correlation Between "+x_label+" length and Number of Network Parameters for", filter_val, df_temp[x_col].corr(df_temp["model_params"], method="spearman"))
# Out:
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for lstm -0.2581988897471611
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for gru nan
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for elman -0.9486832980505139
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for bidirelamn -0.19999999999999998
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for bidirlstm nan
# Spearman Correlation Between Number of Patterns length and Number of Network Parameters for bidirgru nan

# %%
print("\\begin{table}[h!]")
print("\\begin{center}")
print("\\begin{tabular}{ |c|c| } ")

print(" \\toprule")
print(" RNN  &    Spearman Correlation Coefficient \\\\")
print(" \\midrule")

filter_col = "nn_type"
filter_col_1 = x_col
for filter_val in sorted(df[filter_col].unique()):
    df_temp = df[df[filter_col] == filter_val]
    df_temp = df_temp.groupby([x_col, "nn_type"]).agg({"model_params": "mean"}).to_records()
    df_temp = pd.DataFrame.from_records(df_temp)
    df_temp[x_col] = df_temp[x_col].astype(float)
    df_temp["model_params"] = df_temp["model_params"].astype(float)
    
    print(" ",filter_val, " & ", df_temp[x_col].corr(df_temp["model_params"], method="spearman"), "\\\\")

print(" \\hline")
print("\\end{tabular}")
print("\\caption{Correlation between Area of patterns retained \\\\ and the number of network parameters \\\\ one hot encoded}")
print("\\label{tab:Area of patterns vs num network parameters one hot encoded}")
print("\\end{center}")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# \begin{center}
# \begin{tabular}{ |c|c| }
#  \toprule
#  RNN  &    Spearman Correlation Coefficient \\
#  \midrule
#   bidirelamn  &  -0.19999999999999998 \\
#   bidirgru  &  nan \\
#   bidirlstm  &  nan \\
#   elman  &  -0.9486832980505139 \\
#   gru  &  nan \\
#   lstm  &  -0.2581988897471611 \\
#  \hline
# \end{tabular}
# \caption{Correlation between Area of patterns retained \\ and the number of network parameters}
# \label{tab:Area of patterns vs num network parameters}
# \end{center}
# \end{table}

# %% [markdown]
# ### Pattern Area retention

# %%
df_cap = df.groupby(["nn_type"]).agg({"model_params" : "sum", "area": "sum"})
df_cap["capacity_ratio"] = df_cap["area"]/df_cap["model_params"]
df_cap
# Out:
#             model_params  area  capacity_ratio
# nn_type
# bidirelamn       1363320  6082        0.004461
# bidirgru         1375920  6120        0.004448
# bidirlstm        1375920  6120        0.004448
# elman            1411200  6182        0.004381
# gru              1834560  7140        0.003892
# lstm             1828512  7046        0.003853

# %%
print("\\begin{table}[h!]")
print("\\begin{center}")
print("\\begin{tabular}{ |c|c| } ")

print(" \\toprule")
print(" RNN  &    Pattern Capacity Per Parameter \\\\")
print(" \\midrule")

for i, r in df_cap.reset_index().iterrows():
    print(" ",r["nn_type"], " & ", round(r["capacity_ratio"], 7), "\\\\")

    
print(" \\hline")
print("\\end{tabular}")
print("\\caption{Area of patterns retained \\\\ per single network parameter}")
print("\\label{tab:Area of patterns single param one hot encoded }")
print("\\end{center}")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# \begin{center}
# \begin{tabular}{ |c|c| }
#  \toprule
#  RNN  &    Pattern Capacity Per Parameter \\
#  \midrule
#   bidirelamn  &  0.0044612 \\
#   bidirgru  &  0.0044479 \\
#   bidirlstm  &  0.0044479 \\
#   elman  &  0.0043807 \\
#   gru  &  0.0038919 \\
#   lstm  &  0.0038534 \\
#  \hline
# \end{tabular}
# \caption{Area of patterns retained \\ per single network parameter}
# \label{tab:Area of patterns single param one hot encoded }
# \end{center}
# \end{table}

# %% [markdown]
# ## 2. Investigate which activation function lead to the highest retention of length of pattern

# %%
print("\\begin{table}[h!]")
print("\\begin{center}")
print("\\begin{tabular}{ |c|c| } ")
print(" \\toprule")
print(" Activation function  &    Spearman Correlation Coefficient \\\\")
print(" \\midrule")

filter_col = "activation_func"
filter_col_1 = x_col
for filter_val in sorted(df[filter_col].unique()):
    df_temp = df[(df[filter_col] == filter_val)]
    df_temp = df_temp.groupby([filter_col_1]).agg({"model_params": "mean"}).to_records()
    df_temp = pd.DataFrame.from_records(df_temp)
    df_temp[filter_col_1] = df_temp[filter_col_1].astype(float)
    df_temp["model_params"] = df_temp["model_params"].astype(float)
    
    print(" ",filter_val, " & ", df_temp[filter_col_1].corr(df_temp["model_params"], method='spearman', ), "\\\\")
    
    

print(" \\hline")
print("\\end{tabular}")
print("\\caption{Correlation between Area of patterns retained \\\\ and the number of network parameters \\\\ for each activation function}")
print("\\label{tab:Area of patterns vs num network parameters for each activation function one hot encoded }")
print("\\end{center}")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# \begin{center}
# \begin{tabular}{ |c|c| }
#  \toprule
#  Activation function  &    Spearman Correlation Coefficient \\
#  \midrule
#   elu  &  nan \\
#   hard_sigmoid  &  nan \\
#   linear  &  nan \\
#   relu  &  nan \\
#   selu  &  -0.19999999999999998 \\
#   sigmoid  &  nan \\
#   softmax  &  -0.9486832980505139 \\
#   softplus  &  nan \\
#   softsign  &  nan \\
#   tanh  &  nan \\
#  \hline
# \end{tabular}
# \caption{Correlation between Area of patterns retained \\ and the number of network parameters \\ for each activation function}
# \label{tab:Area of patterns vs num network parameters for each activation function one hot encoded }
# \end{center}
# \end{table}

# %%
filter_col = "activation_func"
filter_1 = "area"
x_col = "area"
x_label = "Number of Patterns"
plot_by_filter(x_col=x_col, 
               y_col="model_params",
               x_label=x_label,
               y_label='Number of network parameters',
               title="Effect of the number of parameters on the ability to retain patterns" + 
                       "\n in a neural network over all activation functions", 
               hue="activation_func",
              filter_col=filter_col, filter_val=None, df=df)

# %%
df_g = df.groupby(["activation_func", "model_params"]).agg({"area" : "mean"}).reset_index()

fig = plot_line_sub_plots(df_g, 
            x="model_params", y="area", hue="activation_func",
            x_label='Number of Parameters in Model', y_label='Average Area \n of Patterns retained')
fig.savefig("Images/AreaPatternsVsParametersActFunc_exp3_2.pdf", bbox_inches='tight')

# %% [markdown]
# ### Correlation of activation functions  ∝ area of pattern

# %%
df[filter_col].unique()
# Out:
# array(['softmax', 'elu', 'selu', 'softplus', 'softsign', 'tanh',
#        'sigmoid', 'hard_sigmoid', 'relu', 'linear'], dtype=object)

# %%
filter_col = "activation_func"
filter_col_1="area"
df_correlation_matrix = pd.DataFrame(columns=df["nn_type"].unique())
df_correlation_matrix["activation_func"] = df[filter_col].unique()
df_correlation_matrix.index =  df_correlation_matrix["activation_func"]
del df_correlation_matrix["activation_func"]
for filter_val in df[filter_col].unique():
    for filter_val_1 in df["nn_type"].unique():
        df_temp = df[(df["nn_type"] == filter_val_1) & (df["activation_func"] == filter_val)]
        df_temp["model_params"] = df_temp["model_params"].astype(float)
        df_correlation_matrix.at[filter_val, filter_val_1] =   df_temp[filter_col_1].corr(df_temp["model_params"], method="spearman")
        print("df_correlation_matrix Correlation Between "+x_label+" and Number of Network Parameters for", filter_val_1 + " "+ filter_val, df_temp[filter_col_1].corr(df_temp["model_params"], method="spearman"), df_temp[filter_col_1].cov(df_temp["model_params"]))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm softmax -0.006445277967420237 -3.435248296007741
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru softmax 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman softmax -0.062214331192308306 -295.84326018808787
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn softmax 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm softmax 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru softmax 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm elu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru elu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman elu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn elu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm elu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru elu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm selu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru selu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman selu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn selu 0.007559909767214623 13.80821917808217
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm selu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru selu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm softplus 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru softplus 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman softplus 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn softplus 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm softplus 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru softplus 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm softsign 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru softsign 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman softsign 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn softsign 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm softsign 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru softsign 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm tanh 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru tanh 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman tanh 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn tanh 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm tanh 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru tanh 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm sigmoid 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru sigmoid 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm hard_sigmoid 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru hard_sigmoid 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman hard_sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn hard_sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm hard_sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru hard_sigmoid 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm relu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru relu 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman relu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn relu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm relu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru relu 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for lstm linear 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for gru linear 0.0 3.386920373789811e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for elman linear 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirelamn linear 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirlstm linear 0.0 3.298948416029037e-14
# df_correlation_matrix Correlation Between Number of Patterns and Number of Network Parameters for bidirgru linear 0.0 3.298948416029037e-14

# %%
df_correlation_matrix
# Out:
#                       lstm       gru     elman bidirelamn bidirlstm  bidirgru
# activation_func
# softmax         -0.0207032         0         0          0         0         0
# elu                0.30035         0  -0.30035          0  0.313625   0.30035
# selu              -0.30035   0.30035         0          0         0  0.313625
# softplus                 0         0   0.30035          0         0         0
# softsign                 0   0.30035         0          0         0  0.267131
# tanh              0.313625   0.30035         0          0         0   0.37551
# sigmoid                  0         0  0.313625          0         0         0
# hard_sigmoid             0         0         0          0         0         0
# relu               0.30035  0.313625         0          0  0.313625         0
# linear            0.313625   0.30035         0          0         0   0.37551

# %%
df_correlation_matrix.sort_index(inplace=True)
df_correlation_matrix = df_correlation_matrix[sorted(df_correlation_matrix.columns)]
for c in df_correlation_matrix.columns:
    df_correlation_matrix[c] = df_correlation_matrix[c].apply(lambda x: round(x, 4)) 

df_correlation_matrix.sort_index(inplace=True)
print("\\begin{table}[h!]")
print("{Activation function} &  bidirelamn &  bidirgru &  bidirlstm &   elman &     gru &    lstm \\\\")
print("\\midrule")
print(df_correlation_matrix.to_latex())
print("\\caption{Correlation between Area of patterns retained \\\\ and the number of network parameters \\\\ per activation function for each RNN}")
print("\\label{tab:Area of patterns per Activation function vs num network parameters for each RNN}")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# {Activation function} &  bidirelamn &  bidirgru &  bidirlstm &   elman &     gru &    lstm \\
# \midrule
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  bidirelamn &  bidirgru &  bidirlstm &   elman &     gru &    lstm \\
# activation\_func &             &           &            &         &         &         \\
# \midrule
# elu             &         0.0 &    0.3004 &     0.3136 & -0.3004 &  0.0000 &  0.3004 \\
# hard\_sigmoid    &         0.0 &    0.0000 &     0.0000 &  0.0000 &  0.0000 &  0.0000 \\
# linear          &         0.0 &    0.3755 &     0.0000 &  0.0000 &  0.3004 &  0.3136 \\
# relu            &         0.0 &    0.0000 &     0.3136 &  0.0000 &  0.3136 &  0.3004 \\
# selu            &         0.0 &    0.3136 &     0.0000 &  0.0000 &  0.3004 & -0.3004 \\
# sigmoid         &         0.0 &    0.0000 &     0.0000 &  0.3136 &  0.0000 &  0.0000 \\
# softmax         &         0.0 &    0.0000 &     0.0000 &  0.0000 &  0.0000 & -0.0207 \\
# softplus        &         0.0 &    0.0000 &     0.0000 &  0.3004 &  0.0000 &  0.0000 \\
# softsign        &         0.0 &    0.2671 &     0.0000 &  0.0000 &  0.3004 &  0.0000 \\
# tanh            &         0.0 &    0.3755 &     0.0000 &  0.0000 &  0.3004 &  0.3136 \\
# \bottomrule
# \end{tabular}
#
# \caption{Correlation between Area of patterns retained \\ and the number of network parameters \\ per activation function for each RNN}
# \label{tab:Area of patterns per Activation function vs num network parameters for each RNN}
# \end{table}

# %% [markdown]
# ### Sequence Area Capacity

# %%
df_cap = df.groupby(["nn_type", "activation_func"]).agg({"model_params" : "sum", "area": "sum"})
df_cap["capacity_ratio"] = df_cap["area"]/df_cap["model_params"]
df_cap = pd.DataFrame(df_cap.to_records())
df_cap = df_cap.pivot(index="activation_func", columns="nn_type", values="capacity_ratio")
df_cap
# Out:
# nn_type          bidirelamn  bidirgru  bidirlstm     elman       gru      lstm
# activation_func
# elu                0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# hard_sigmoid       0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# linear             0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# relu               0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# selu               0.004592  0.004448   0.004448  0.004448  0.003892  0.003892
# sigmoid            0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# softmax            0.004448  0.004448   0.004448  0.003899  0.003892  0.003495
# softplus           0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# softsign           0.004448  0.004448   0.004448  0.004448  0.003892  0.003892
# tanh               0.004448  0.004448   0.004448  0.004448  0.003892  0.003892

# %%
df_cap.sort_index(inplace=True)
df_cap = df_cap[sorted(df_cap.columns)]
# for c in df_cap.columns:
#     df_cap[c] = df_cap[c].apply(lambda x: round(x, 8)) 

df_cap.sort_index(inplace=True)
print("\\begin{table}[h!]")
print("{Activation function} &  bidirelamn &  bidirgru &  bidirlstm &   elman &     gru &    lstm \\\\")
print("\\midrule")
print(df_cap.to_latex())
print("\\caption{Per parameter capacity between Area of patterns retained \\\\ and the number of network parameters \\\\ per activation function for each RNN}")
print("\\label{tab:Area of patterns per Activation function vs num network parameters for each RNN one hot encoded }")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# {Activation function} &  bidirelamn &  bidirgru &  bidirlstm &   elman &     gru &    lstm \\
# \midrule
# \begin{tabular}{lrrrrrr}
# \toprule
# nn\_type &  bidirelamn &  bidirgru &  bidirlstm &     elman &       gru &      lstm \\
# activation\_func &             &           &            &           &           &           \\
# \midrule
# elu             &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# hard\_sigmoid    &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# linear          &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# relu            &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# selu            &    0.004592 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# sigmoid         &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# softmax         &    0.004448 &  0.004448 &   0.004448 &  0.003899 &  0.003892 &  0.003495 \\
# softplus        &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# softsign        &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# tanh            &    0.004448 &  0.004448 &   0.004448 &  0.004448 &  0.003892 &  0.003892 \\
# \bottomrule
# \end{tabular}
#
# \caption{Per parameter capacity between Area of patterns retained \\ and the number of network parameters \\ per activation function for each RNN}
# \label{tab:Area of patterns per Activation function vs num network parameters for each RNN one hot encoded }
# \end{table}

# %% [markdown]
#             # TOTOTOTOTOTODOODODODODOODODODO

# %% [markdown]
# ## 3. Relationship between the length of pattern and number of layers

# %%
df["num_layers"] = df["nodes_in_layer"].apply(len)
df.groupby(["num_layers", "model_params"]).agg({"area": "mean"})
# Out:
#                              area
# num_layers model_params
# 1          504           7.846354
#            1008          7.846154
#            1512          7.846154
#            2016          7.846154
#            2520          7.847742
#            3024          7.846154
#            3528          7.785185

# %%
df_g = df.groupby(["activation_func", "num_layers"]).agg({"area" : "mean"}).reset_index()
fig = plot_line_sub_plots(df_g, 
            x="num_layers", y="area", hue="activation_func",
            x_label='Number of Layers in Model', y_label='Average Area \n of Patterns retained')
fig.savefig("Images/AreaPatternsVsNumLayersActFunc_exp3_2.pdf", bbox_inches='tight')

# %%
df_cap = df.groupby(["nn_type", "activation_func", "num_layers"]).agg({"model_params" : "sum", "area": "sum"})
df_cap = pd.DataFrame(df_cap.to_records())
df_cap["capacity_ratio"] = df_cap["area"]/df_cap["model_params"]
# df_cap = df_cap.pivot(index="activation_func", columns="nn_type", values="capacity_ratio")
df_cap
# Out:
#        nn_type activation_func  num_layers  model_params  area  capacity_ratio
# 0   bidirelamn             elu           1        137592   612        0.004448
# 1   bidirelamn    hard_sigmoid           1        137592   612        0.004448
# 2   bidirelamn          linear           1        137592   612        0.004448
# 3   bidirelamn            relu           1        137592   612        0.004448
# 4   bidirelamn            selu           1        124992   574        0.004592
# 5   bidirelamn         sigmoid           1        137592   612        0.004448
# 6   bidirelamn         softmax           1        137592   612        0.004448
# 7   bidirelamn        softplus           1        137592   612        0.004448
# 8   bidirelamn        softsign           1        137592   612        0.004448
# 9   bidirelamn            tanh           1        137592   612        0.004448
# 10    bidirgru             elu           1        137592   612        0.004448
# 11    bidirgru    hard_sigmoid           1        137592   612        0.004448
# 12    bidirgru          linear           1        137592   612        0.004448
# 13    bidirgru            relu           1        137592   612        0.004448
# 14    bidirgru            selu           1        137592   612        0.004448
# 15    bidirgru         sigmoid           1        137592   612        0.004448
# 16    bidirgru         softmax           1        137592   612        0.004448
# 17    bidirgru        softplus           1        137592   612        0.004448
# 18    bidirgru        softsign           1        137592   612        0.004448
# 19    bidirgru            tanh           1        137592   612        0.004448
# 20   bidirlstm             elu           1        137592   612        0.004448
# 21   bidirlstm    hard_sigmoid           1        137592   612        0.004448
# 22   bidirlstm          linear           1        137592   612        0.004448
# 23   bidirlstm            relu           1        137592   612        0.004448
# 24   bidirlstm            selu           1        137592   612        0.004448
# 25   bidirlstm         sigmoid           1        137592   612        0.004448
# 26   bidirlstm         softmax           1        137592   612        0.004448
# 27   bidirlstm        softplus           1        137592   612        0.004448
# 28   bidirlstm        softsign           1        137592   612        0.004448
# 29   bidirlstm            tanh           1        137592   612        0.004448
# 30       elman             elu           1        137592   612        0.004448
# 31       elman    hard_sigmoid           1        137592   612        0.004448
# 32       elman          linear           1        137592   612        0.004448
# 33       elman            relu           1        137592   612        0.004448
# 34       elman            selu           1        137592   612        0.004448
# 35       elman         sigmoid           1        137592   612        0.004448
# 36       elman         softmax           1        172872   674        0.003899
# 37       elman        softplus           1        137592   612        0.004448
# 38       elman        softsign           1        137592   612        0.004448
# 39       elman            tanh           1        137592   612        0.004448
# 40         gru             elu           1        183456   714        0.003892
# 41         gru    hard_sigmoid           1        183456   714        0.003892
# 42         gru          linear           1        183456   714        0.003892
# 43         gru            relu           1        183456   714        0.003892
# 44         gru            selu           1        183456   714        0.003892
# 45         gru         sigmoid           1        183456   714        0.003892
# 46         gru         softmax           1        183456   714        0.003892
# 47         gru        softplus           1        183456   714        0.003892
# 48         gru        softsign           1        183456   714        0.003892
# 49         gru            tanh           1        183456   714        0.003892
# 50        lstm             elu           1        183456   714        0.003892
# 51        lstm    hard_sigmoid           1        183456   714        0.003892
# 52        lstm          linear           1        183456   714        0.003892
# 53        lstm            relu           1        183456   714        0.003892
# 54        lstm            selu           1        183456   714        0.003892
# 55        lstm         sigmoid           1        183456   714        0.003892
# 56        lstm         softmax           1        177408   620        0.003495
# 57        lstm        softplus           1        183456   714        0.003892
# 58        lstm        softsign           1        183456   714        0.003892
# 59        lstm            tanh           1        183456   714        0.003892

# %%
df_cap["capacity_ratio_diff"] = [0]*df_cap.shape[0]
prev_nn = ""
prev_activation = ""
prev_cap_ratio = ""
for i, row in df_cap.iterrows():
    if row["nn_type"] == prev_nn and row["activation_func"] == prev_activation:
        df_cap.iloc[i, df_cap.columns.get_loc('capacity_ratio_diff')] = row["capacity_ratio"] - prev_cap_ratio
    else:
        df_cap.iloc[i, df_cap.columns.get_loc('capacity_ratio_diff')] = np.nan
    prev_nn = row["nn_type"]
    prev_activation = row["activation_func"]
    prev_cap_ratio = row["capacity_ratio"]
df_cap
# Out:
#        nn_type activation_func  num_layers  model_params  area  capacity_ratio  capacity_ratio_diff
# 0   bidirelamn             elu           1        137592   612        0.004448                  NaN
# 1   bidirelamn    hard_sigmoid           1        137592   612        0.004448                  NaN
# 2   bidirelamn          linear           1        137592   612        0.004448                  NaN
# 3   bidirelamn            relu           1        137592   612        0.004448                  NaN
# 4   bidirelamn            selu           1        124992   574        0.004592                  NaN
# 5   bidirelamn         sigmoid           1        137592   612        0.004448                  NaN
# 6   bidirelamn         softmax           1        137592   612        0.004448                  NaN
# 7   bidirelamn        softplus           1        137592   612        0.004448                  NaN
# 8   bidirelamn        softsign           1        137592   612        0.004448                  NaN
# 9   bidirelamn            tanh           1        137592   612        0.004448                  NaN
# 10    bidirgru             elu           1        137592   612        0.004448                  NaN
# 11    bidirgru    hard_sigmoid           1        137592   612        0.004448                  NaN
# 12    bidirgru          linear           1        137592   612        0.004448                  NaN
# 13    bidirgru            relu           1        137592   612        0.004448                  NaN
# 14    bidirgru            selu           1        137592   612        0.004448                  NaN
# 15    bidirgru         sigmoid           1        137592   612        0.004448                  NaN
# 16    bidirgru         softmax           1        137592   612        0.004448                  NaN
# 17    bidirgru        softplus           1        137592   612        0.004448                  NaN
# 18    bidirgru        softsign           1        137592   612        0.004448                  NaN
# 19    bidirgru            tanh           1        137592   612        0.004448                  NaN
# 20   bidirlstm             elu           1        137592   612        0.004448                  NaN
# 21   bidirlstm    hard_sigmoid           1        137592   612        0.004448                  NaN
# 22   bidirlstm          linear           1        137592   612        0.004448                  NaN
# 23   bidirlstm            relu           1        137592   612        0.004448                  NaN
# 24   bidirlstm            selu           1        137592   612        0.004448                  NaN
# 25   bidirlstm         sigmoid           1        137592   612        0.004448                  NaN
# 26   bidirlstm         softmax           1        137592   612        0.004448                  NaN
# 27   bidirlstm        softplus           1        137592   612        0.004448                  NaN
# 28   bidirlstm        softsign           1        137592   612        0.004448                  NaN
# 29   bidirlstm            tanh           1        137592   612        0.004448                  NaN
# 30       elman             elu           1        137592   612        0.004448                  NaN
# 31       elman    hard_sigmoid           1        137592   612        0.004448                  NaN
# 32       elman          linear           1        137592   612        0.004448                  NaN
# 33       elman            relu           1        137592   612        0.004448                  NaN
# 34       elman            selu           1        137592   612        0.004448                  NaN
# 35       elman         sigmoid           1        137592   612        0.004448                  NaN
# 36       elman         softmax           1        172872   674        0.003899                  NaN
# 37       elman        softplus           1        137592   612        0.004448                  NaN
# 38       elman        softsign           1        137592   612        0.004448                  NaN
# 39       elman            tanh           1        137592   612        0.004448                  NaN
# 40         gru             elu           1        183456   714        0.003892                  NaN
# 41         gru    hard_sigmoid           1        183456   714        0.003892                  NaN
# 42         gru          linear           1        183456   714        0.003892                  NaN
# 43         gru            relu           1        183456   714        0.003892                  NaN
# 44         gru            selu           1        183456   714        0.003892                  NaN
# 45         gru         sigmoid           1        183456   714        0.003892                  NaN
# 46         gru         softmax           1        183456   714        0.003892                  NaN
# 47         gru        softplus           1        183456   714        0.003892                  NaN
# 48         gru        softsign           1        183456   714        0.003892                  NaN
# 49         gru            tanh           1        183456   714        0.003892                  NaN
# 50        lstm             elu           1        183456   714        0.003892                  NaN
# 51        lstm    hard_sigmoid           1        183456   714        0.003892                  NaN
# 52        lstm          linear           1        183456   714        0.003892                  NaN
# 53        lstm            relu           1        183456   714        0.003892                  NaN
# 54        lstm            selu           1        183456   714        0.003892                  NaN
# 55        lstm         sigmoid           1        183456   714        0.003892                  NaN
# 56        lstm         softmax           1        177408   620        0.003495                  NaN
# 57        lstm        softplus           1        183456   714        0.003892                  NaN
# 58        lstm        softsign           1        183456   714        0.003892                  NaN
# 59        lstm            tanh           1        183456   714        0.003892                  NaN

# %%
df_cap_group = df_cap.groupby(["activation_func", "num_layers"]).agg({"capacity_ratio": "mean"}).reset_index()
df_cap_group
# Out:
#   activation_func  num_layers  capacity_ratio
# 0             elu           1        0.004263
# 1    hard_sigmoid           1        0.004263
# 2          linear           1        0.004263
# 3            relu           1        0.004263
# 4            selu           1        0.004287
# 5         sigmoid           1        0.004263
# 6         softmax           1        0.004105
# 7        softplus           1        0.004263
# 8        softsign           1        0.004263
# 9            tanh           1        0.004263

# %%
fig = plot_line_sub_plots(df_cap_group, 
            x="num_layers", y="capacity_ratio", hue="activation_func",
            x_label='Number of Layers', y_label='Area Capacity per parameter')

fig.savefig("Images/AreaCapacityPerParameterVsNumLayersActFunc_exp3_2.pdf", bbox_inches='tight')

# %%
print("\\begin{table}[h!]")

latex_str = df_cap.groupby(["nn_type", "num_layers", "activation_func"]).agg({"capacity_ratio":"max"}).unstack().to_latex()
latex_str = latex_str.replace("nn\\_type", "RNN Type")
latex_str = latex_str.replace("num\\_layers", "Number of Layers")
latex_str = latex_str.replace("capacity\\_ratio", "Area Capacity Per Parameter")
print(latex_str)


print("""\\caption{Per parameter Area capacity for each RNN \\\\ 
            per activation function  \\\\  
              at various layer depths}""")
print("\\label{tab:Area of patterns per Activation Per RNN Per Layer}")
print("\\end{table}")
# Out:
# \begin{table}[h!]
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#      & {} & \multicolumn{10}{l}{Area Capacity Per Parameter} \\
#      & activation\_func &            elu & hard\_sigmoid &    linear &      relu &      selu &   sigmoid &   softmax &  softplus &  softsign &      tanh \\
# RNN Type & Number of Layers &                &              &           &           &           &           &           &           &           &           \\
# \midrule
# bidirelamn & 1 &       0.004448 &     0.004448 &  0.004448 &  0.004448 &  0.004592 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 \\
# bidirgru & 1 &       0.004448 &     0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 \\
# bidirlstm & 1 &       0.004448 &     0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 \\
# elman & 1 &       0.004448 &     0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.004448 &  0.003899 &  0.004448 &  0.004448 &  0.004448 \\
# gru & 1 &       0.003892 &     0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 \\
# lstm & 1 &       0.003892 &     0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003892 &  0.003495 &  0.003892 &  0.003892 &  0.003892 \\
# \bottomrule
# \end{tabular}
#
# \caption{Per parameter Area capacity for each RNN \\
#             per activation function  \\
#               at various layer depths}
# \label{tab:Area of patterns per Activation Per RNN Per Layer}
# \end{table}
